# %%
import numpy as np
import pandas as pd

from google.colab import files
files.upload()
train = pd.read_csv('train_XnW6LSF.csv')
train.head()
# Out:
#      <input type="file" id="files-ef5c72eb-ecb1-4876-9958-1418d0798779" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ef5c72eb-ecb1-4876-9958-1418d0798779">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
train.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
Tier_1 = train[train.Outlet_Location_Type ==  'Tier 1']
Tier_2 = train[train.Outlet_Location_Type ==  'Tier 2']
Tier_3= train[train.Outlet_Location_Type ==  'Tier 3']

# %%
Tier_1.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  1860.000000      2388.000000  2388.000000                2388.000000
# mean     12.892124         0.071205   140.870106                1995.125628
# std       4.666734         0.057404    62.129731                   5.467745
# min       4.555000         0.000000    32.455800                1985.000000
# 25%       8.773750         0.028059    93.535700                1997.000000
# 50%      12.625000         0.056450   143.264100                1997.000000
# 75%      17.000000         0.102684   185.099000                1999.000000
# max      21.350000         0.328391   266.888400                1999.000000
#
#        Item_Outlet_Sales
# count        2388.000000
# mean         1876.909159
# std          1561.649293
# min            33.955800
# 25%           593.727150
# 50%          1487.397200
# 75%          2803.018000
# max          9779.936200

# %%
Tier_2.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  2785.000000      2785.000000  2785.000000                2785.000000
# mean     12.768628         0.061038   141.167196                2004.330341
# std       4.607141         0.044601    62.153975                   2.054055
# min       4.555000         0.000000    32.055800                2002.000000
# 25%       8.750000         0.026060    94.477800                2002.000000
# 50%      12.500000         0.051766   143.281200                2004.000000
# 75%      16.750000         0.088864   185.358200                2007.000000
# max      21.350000         0.188620   266.888400                2007.000000
#
#        Item_Outlet_Sales
# count        2785.000000
# mean         2323.990559
# std          1520.543543
# min            99.870000
# 25%          1171.808000
# 50%          2004.058000
# 75%          3110.617600
# max          9664.752800

# %%
Tier_3.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  2415.000000      3350.000000  3350.000000                3350.000000
# mean     12.933745         0.066751   140.935232                1994.358507
# std       4.667359         0.052269    62.496982                  10.055867
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.820000         0.027502    93.609400                1985.000000
# 50%      12.650000         0.053906   142.248300                1987.000000
# 75%      17.000000         0.095613   186.532550                2009.000000
# max      21.350000         0.311090   266.688400                2009.000000
#
#        Item_Outlet_Sales
# count        3350.000000
# mean         2279.627651
# std          1912.451333
# min            33.290000
# 25%           731.381300
# 50%          1812.307600
# 75%          3307.694400
# max         13086.964800

# %%
Tier_1_Dairy=Tier_1[Tier_1.Item_Type=='Dairy'].Item_Outlet_Sales
Tier_1_Dairy.describe()
# Out:
# count     205.000000
# mean     1809.322867
# std      1550.040020
# min        40.613800
# 25%       578.580200
# 50%      1338.258000
# 75%      3020.734600
# max      7833.802800
# Name: Item_Outlet_Sales, dtype: float64

# %%
Tier_2_Dairy=Tier_2[Tier_2.Item_Type=='Dairy'].Item_Outlet_Sales
Tier_2_Dairy.describe()
# Out:
# count     214.000000
# mean     2456.416209
# std      1834.315342
# min       181.097600
# 25%      1133.857400
# 50%      1960.781000
# 75%      3444.183400
# max      9664.752800
# Name: Item_Outlet_Sales, dtype: float64

# %%
Tier_3_Dairy=Tier_3[Tier_3.Item_Type == 'Dairy'].Item_Outlet_Sales
Tier_3_Dairy.describe()
# Out:
# count      263.000000
# mean      2380.265379
# std       2102.539061
# min         47.271800
# 25%        783.979500
# 50%       1791.667800
# 75%       3458.498100
# max      10256.649000
# Name: Item_Outlet_Sales, dtype: float64

# %%
Outlets=pd.concat([train['Outlet_Establishment_Year'],train['Outlet_Identifier'],train['Outlet_Type']],axis=1)
duplicates_dropped=Outlets.drop_duplicates()
duplicates_dropped
# Out:
#     Outlet_Establishment_Year Outlet_Identifier        Outlet_Type
# 0                        1999            OUT049  Supermarket Type1
# 1                        2009            OUT018  Supermarket Type2
# 3                        1998            OUT010      Grocery Store
# 4                        1987            OUT013  Supermarket Type1
# 7                        1985            OUT027  Supermarket Type3
# 8                        2002            OUT045  Supermarket Type1
# 9                        2007            OUT017  Supermarket Type1
# 11                       1997            OUT046  Supermarket Type1
# 19                       2004            OUT035  Supermarket Type1
# 23                       1985            OUT019      Grocery Store

# %%
duplicates_dropped.sort_values( by=['Outlet_Establishment_Year','Outlet_Identifier'], ascending=True)
# Out:
#     Outlet_Establishment_Year Outlet_Identifier        Outlet_Type
# 23                       1985            OUT019      Grocery Store
# 7                        1985            OUT027  Supermarket Type3
# 4                        1987            OUT013  Supermarket Type1
# 11                       1997            OUT046  Supermarket Type1
# 3                        1998            OUT010      Grocery Store
# 0                        1999            OUT049  Supermarket Type1
# 8                        2002            OUT045  Supermarket Type1
# 19                       2004            OUT035  Supermarket Type1
# 9                        2007            OUT017  Supermarket Type1
# 1                        2009            OUT018  Supermarket Type2

# %%
outlet_size_high=train[train.Outlet_Size=='High']
outlet_size_high.Item_Fat_Content.value_counts()
# Out:
# Low Fat    556
# Regular    313
# LF          32
# low fat     18
# reg         13
# Name: Item_Fat_Content, dtype: int64

# %%
MRP_higher_200=train[train['Item_MRP']>200]
MRP_higher_200['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    862
# Regular    488
# LF          49
# low fat     22
# reg         19
# Name: Item_Fat_Content, dtype: int64

# %%
max(Tier_2['Item_Outlet_Sales'])
# Out:
# 9664.7528

# %%
max(Tier_3['Item_Outlet_Sales'])
# Out:
# 13086.9648
